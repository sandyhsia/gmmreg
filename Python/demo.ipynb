# %%
cd /home/mech-mind-050/projects/gmmreg/Python/build/lib.linux-x86_64-3.5/gmmreg/
# Out:
# /home/mech-mind-050/projects/gmmreg/Python/build/lib.linux-x86_64-3.5/gmmreg

# %%
pwd
# Out:
# '/home/mech-mind-050/projects/gmmreg/Python/build/lib.linux-x86_64-3.5/gmmreg'

# %%
import _demo

# %%
config_file = '/home/mech-mind-050/projects/gmmreg/data/fish_partial.ini'

# %%
_demo.test(config_file)
# Out:
# nL, n, d 78 25 2
# Elasped time is 0.3256649971008301 seconds
# after_tps
# [[-0.01275133  0.64513296]
#  [ 0.01547208  0.65944224]
#  [ 0.11346905  0.44175277]
#  [ 0.14831723  0.43693608]
#  [ 0.16091347  0.42866752]
#  [ 0.06171891  0.67353127]
#  [ 0.07546235  0.68985365]
#  [ 0.20665081  0.41891855]
#  [ 0.10605056  0.71637085]
#  [ 0.25324061  0.40865916]
#  [ 0.27927332  0.39194104]
#  [ 0.16072809  0.6045677 ]
#  [ 0.17699298  0.57740925]
#  [ 0.30685365  0.38168837]
#  [ 0.13580914  0.73597171]
#  [ 0.15783159  0.64230538]
#  [ 0.23001603  0.50583027]
#  [ 0.24106016  0.48792046]
#  [ 0.25558524  0.46729826]
#  [ 0.33959804  0.36473742]
#  [ 0.13667588  0.75952213]
#  [ 0.1753476   0.67419886]
#  [ 0.21597242  0.57876299]
#  [ 0.24440877  0.51301729]
#  [ 0.27890524  0.45377641]
#  [ 0.29855142  0.43811929]
#  [ 0.37375586  0.35474705]
#  [ 0.15126381  0.7710989 ]
#  [ 0.33582276  0.41783006]
#  [ 0.35048095  0.4009561 ]
#  [ 0.39837975  0.33945976]
# ...

# %%
config_file = '/home/mech-mind-050/projects/gmmreg/data/face.ini'
_demo.test(config_file)
# Out:
# nL, n, d 392 125 3
# Elasped time is 1.1996679306030273 seconds
# after_tps
# [[-1.16840696  0.58790401  0.34556537]
#  [-1.11540904  0.69156779  0.70754287]
#  [-1.10343632  0.89986695 -0.11983242]
#  ...
#  [ 1.12327515  1.14465502 -0.10931563]
#  [ 1.08467244  0.85037022  0.62785615]
#  [ 1.10279315  0.80017144  0.30520388]]

# %%
import _plotting
